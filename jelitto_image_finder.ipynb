# %%
import pandas as pd
import numpy as np
import requests
import urllib
from lxml.html import fromstring
import threading
import concurrent.futures
from collections import defaultdict
import re
import logging

# %%
# Read in seed spreadsheet
jelitto = pd.read_excel('jelitto_pricelist.xls')

# %%
# Don't truncate text
pd.set_option('display.max_colwidth', -1)

# %%
# Subset of rows to test
jelitto = jelitto.iloc[0:250, :]

# %%
# Check dataframe
jelitto.head()
# Out:
#   Characteristic (GOLD NUGGET SEED® etc.) Herbs/Ornamental Grasses Item No.  \
# 0  NaN                                     NaN                      AA008
# 1  NaN                                     NaN                      AA001
# 2  NaN                                     NaN                      AA002
# 3  NaN                                     NaN                      AA011
# 4  NaN                                     NaN                      AA003
#
#       Genus      Species  Series Variety Marketing Name Synonyme  \
# 0  ABUTILON  vitifolium    NaN    NaN     NaN            NaN
# 1  ACAENA    buchananii    NaN    NaN     NaN            NaN
# 2  ACAENA    caesiiglauca  NaN    NaN     NaN            NaN
# 3  ACAENA    fissistipula  NaN    NaN     NaN            NaN
# 4  ACAENA    inermis       NaN    NaN     NaN            NaN
#
#                           Common Names  ...  Height to (cm) Flowering from  \
# 0  Indian Mallow, Flowering Maple       ...  150             May
# 1  New Zealand Bur, Bidibidi, Piripiri  ...  10              July
# 2  New Zealand Bur, Bidibidi, Piripiri  ...  10              July
# 3  New Zealand Burr                     ...  10              July
# 4  New Zealand Burr, Sheep's Burr       ...  10              July
#
#   Flowering to Hardiness Zone from Hardiness Zone to  g/1.000 Plants  \
# 0  June         Z8                  Z11               10.0
# 1  August       Z5                  Z8                5.0
# 2  August       Z5                  Z8                5.0
# 3  August       Z5                  Z8                5.0
# 4  August       Z5                  Z8                8.0
#
#    Flower Habit                                    Catalogue Description  \
# 0  NaN           mostly blue, rarely white, large Mallow flowers
# 1  NaN           blue-green foliage
# 2  NaN           grey-green leaves
# 3  NaN           fine, blue-green leaves, white flowers with red anthers
# 4  NaN           large, unprickled blossom heads, green foliage
#
#            Restrictions  Alphabetical Sorting
# 0  NaN                   10002000
# 1  Australia:prohibited  10003500
# 2  Australia:prohibited  10004000
# 3  Australia:prohibited  10004500
# 4  Australia:prohibited  10005000
#
# [5 rows x 29 columns]

# %%
# Add row for image url
image_url = jelitto['Item No.'].apply(lambda row: 'https://www.jelitto.com/out/pictures/master/product/1/' + row.lower() + '.jpg')

# %%
def response_code_error(url):
    """Confirm that Jelitto has an image of the plant."""
    try:
        return urllib.request.urlopen(url).getcode()
    except urllib.error.URLError:
        return np.nan

# %%
# Save checked urls to a dictionary.
confident_urls = defaultdict(str)

# Threaded Jelitto image url checking.
with concurrent.futures.ThreadPoolExecutor(max_workers=25) as executor:
    check_url = {executor.submit(response_code_error, url): url for url in image_url}
    for future in concurrent.futures.as_completed(check_url):
        url = check_url[future]
        try:
            data = future.result()
            if data == 200:
                confident_urls[re.search(r'\/1\/(.*)\.', url).group(1)] = url
            else:
                confident_urls[re.search(r'\/1\/(.*)\.', url).group(1)] = np.nan 
        except Exception as exc:
            print('%r generated an exception: %s' % (url, exc))

# %%
# Cast confident_urls to a dataframe sorted by index (the Item No.)
df = pd.DataFrame.from_dict(confident_urls, orient='index', columns=['url'])
df.sort_index(inplace=True)

# %%
# Set the index of the jelitto df to Item No & sort
jelitto.set_index('Item No.', inplace=True)
jelitto.sort_index(inplace=True)

# %%
# Add image_url column to jelitto
jelitto['image_url'] = df['url'].values

# %%
# Create list of wikimedia_urls for rows where jelitto had no image 
# and create alternate lookups for the common name to check if the scientific name has no results
wikimedia_urls = []
alternate_lookups = {}
_url = 'https://commons.wikimedia.org/w/index.php?search='
updates = jelitto[jelitto['image_url'].isnull()]
wikimedia_urls = [(ix, _url + x) for ix, x in updates[['Genus', 'Species ']].apply(lambda x: ' '.join(x).lower(), axis=1).iteritems()]
alternate_lookups = {i: _url+'+'.join(x.split(',')[0].split()) for i,x in updates['Common Names'].iteritems() if not isinstance(x, float)}
alternate_urls = []

# %%
def alt_url(url, scientific=False):
    """Test tuple of _id and url to find an image on wikimedia commons."""
    _id = url[0]
    url = url[1]
    page = requests.get(url)
    text = fromstring(page.content)
    try:
        new_url = text.xpath("//li[@class='mw-search-result']//a/@href|//ul[contains(@class, 'gallery')]//img/@src")[0]
        if new_url.lower().endswith(('.png', '.jpg', '.jpeg')):
            if (_id, "https://commons.wikimedia.org"+new_url) not in alternate_urls:
                alternate_urls.append((_id, "https://commons.wikimedia.org"+new_url))
            if scientific:
                del alternate_lookups[_id]
        else:
            if scientific:
                pass # try common name
            else:
                alternate_urls.append((_id, np.nan)) 
    except Exception as e:
        logging.info(f"Exception {e} encountered at {_id} {url}") 
        if scientific:
            pass
        else:
            alternate_urls.append((_id, np.nan))

# %%
# Checking wikimedia urls with scientific name lookup
with concurrent.futures.ThreadPoolExecutor(max_workers=50) as executor:
    # Start the load operations and mark each future with its URL
    check_url = {executor.submit(alt_url, url, scientific=True): url for url in wikimedia_urls}  
    for future in concurrent.futures.as_completed(check_url):
        url = check_url[future]

# %%
# Checking wikimedia common name lookup
if alternate_lookups:
    lookups = [(k,v) for k,v in alternate_lookups.items()]
    with concurrent.futures.ThreadPoolExecutor(max_workers=50) as executor:
        check_url = {executor.submit(alt_url, url): url for url in lookups}
        for future in concurrent.futures.as_completed(check_url):
            url = check_url[future]

# %%
# Cast alternate_urls to df with index aligned to jelitto
altdf = pd.DataFrame(alternate_urls)
altdf.rename({0: '_id', 1: 'image_url'}, axis=1, inplace=True)
altdf.set_index('_id', inplace=True)

# %%
# Replace null values in image_url with urls from alternate_urls
jelitto = jelitto.combine_first(altdf)

# %%
# Check results
jelitto[['Genus', 'Species ', 'image_url']]
# Out:
#              Genus                    Species   \
# AA001  ACAENA       buchananii
# AA002  ACAENA       caesiiglauca
# AA003  ACAENA       inermis
# AA005  ACAENA       microphylla
# AA007  ACAENA       novae-zelandiae
# AA008  ABUTILON     vitifolium
# AA009  ACAENA       saccaticupula
# AA011  ACAENA       fissistipula
# AA012  ACANTHUS     hungaricus
# AA014  ACANTHUS     mollis
# AA015  ACANTHUS     spinosus
# AA017  ACHILLEA     ageratum
# AA019  ACAENA       inermis
# AA021  ACAENA       myriophylla
# AA022  ACHILLEA     clypeolata
# AA024  ACHILLEA     filipendulina
# AA026  ACHILLEA     millefolium
# AA027  ACHILLEA     millefolium
# AA028  ACHILLEA     millefolium
# AA029  ACHILLEA     millefolium
# AA031  ACHILLEA     millefolium
# AA033  ACHILLEA     millefolium
# AA038  ACHILLEA     nana
# AA041  ACHILLEA     nobilis
# AA044  ACHILLEA     ptarmica
# AA048  ACHILLEA     ptarmica
# AA049  ACHILLEA     ptarmica fl. pl.
# AA052  ACHILLEA     ageratifolia
# AA056  ACHILLEA     sibirica ssp. camtschatica
# AA058  ACHILLEA     tomentosa
# ...         ...           ...
# AA528  ANEMONOPSIS  macrophylla f. albiflora
# AA530  ANTHERICUM   liliago
# AA538  ANTHERICUM   ramosum
# AA539  ANTHRISCUS   cerefolium
# AA540  ANTHRISCUS   sylvestris
# AA541  ANTHRISCUS   sylvestris
# AA542  ANTHYLLIS    montana
# AA544  ANTHYLLIS    vulneraria var. coccinea
# AA546  ANTHYLLIS    vulneraria
# AA552  ANTIRRHINUM  braun-blanquetii
# AT280  ALCEA        Ficifolia-Hybr.
# AT282  ALTHAEA      officinalis
# AT285  ALCEA        Ficifolia-Hybr.
# AT286  ALCEA        Rosea-Hybr.
# AT290  ALCEA        rosea plena
# AT292  ALCEA        rosea plena
# AT293  ALCEA        rosea plena
# AT295  ALCEA        rosea plena
# AT297  ALCEA        rosea plena
# AT298  ALCEA        rosea plena
# AT300  ALCEA        rosea plena
# AT301  ALCEA        rosea plena
# AT302  ALCEA        rosea plena
# AT304  ALCEA        rosea plena
# AT308  ALCEA        rosea var. nigra
# AT801  ALCEA        Rosea-Hybr.
# AT802  ALCEA        Rosea-Hybr.
# AT804  ALCEA        Rosea-Hybr.
# AT806  ALCEA        Rosea-Hybr.
# AT808  ALCEA        Rosea-Hybr.
#
#                                                                                                                                                                                image_url
# AA001  https://www.jelitto.com/out/pictures/master/product/1/aa001.jpg
# AA002  https://www.jelitto.com/out/pictures/master/product/1/aa002.jpg
# AA003  https://www.jelitto.com/out/pictures/master/product/1/aa003.jpg
# AA005  https://www.jelitto.com/out/pictures/master/product/1/aa005.jpg
# AA007  https://www.jelitto.com/out/pictures/master/product/1/aa007.jpg
# AA008  https://www.jelitto.com/out/pictures/master/product/1/aa008.jpg
# AA009  https://www.jelitto.com/out/pictures/master/product/1/aa009.jpg
# AA011  https://www.jelitto.com/out/pictures/master/product/1/aa011.jpg
# AA012  https://www.jelitto.com/out/pictures/master/product/1/aa012.jpg
# AA014  https://www.jelitto.com/out/pictures/master/product/1/aa014.jpg
# AA015  https://www.jelitto.com/out/pictures/master/product/1/aa015.jpg
# AA017  https://www.jelitto.com/out/pictures/master/product/1/aa017.jpg
# AA019  https://commons.wikimedia.orghttps://upload.wikimedia.org/wikipedia/commons/thumb/f/f8/Acaena_inermis_%27Purpurea%27_kz01.jpg/120px-Acaena_inermis_%27Purpurea%27_kz01.jpg
# AA021  https://www.jelitto.com/out/pictures/master/product/1/aa021.jpg
# AA022  https://www.jelitto.com/out/pictures/master/product/1/aa022.jpg
# AA024  https://www.jelitto.com/out/pictures/master/product/1/aa024.jpg
# AA026  https://www.jelitto.com/out/pictures/master/product/1/aa026.jpg
# AA027  https://www.jelitto.com/out/pictures/master/product/1/aa027.jpg
# AA028  https://www.jelitto.com/out/pictures/master/product/1/aa028.jpg
# AA029  https://www.jelitto.com/out/pictures/master/product/1/aa029.jpg
